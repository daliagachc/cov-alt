# %%
# load and autoreload
from IPython import get_ipython
# noinspection PyBroadException
try:
    _magic = get_ipython().magic
    _magic('load_ext autoreload')
    _magic('autoreload 2')
except:
    pass
    

import os 
import glob
import sys
import pprint
import datetime as dt
import pandas as pd 
import numpy as np
import matplotlib as mpl
import matplotlib.colors
import matplotlib.pyplot as plt 
import xarray as xr 
import seaborn as sns
import cartopy as crt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
f = './data/south.america.subnational.mortality.txt'

# %%
df = pd.read_csv(f)

# %%
IC,CN,AI,AN,FR,DT,DE = ('iso_code', 'country_name', 'adm1_isocode', 'adm1_name', 'frequency',
       'date', 'deaths')

# %%
nam = df.drop_duplicates([CN,AN])[[CN,AN,AI]]

# %%
con = df.drop_duplicates(CN)[CN]

# %%
for i in con:
    pprint.pprint(nam[nam[CN]==i])
# Out:
#     country_name   adm1_name adm1_isocode
# 0        Bolivia        Beni         BO-B
# 33       Bolivia  Chuquisaca         BO-H
# 66       Bolivia  Cochabamba         BO-C
# 99       Bolivia      La Paz         BO-L
# 132      Bolivia       Oruro         BO-O
# 165      Bolivia       Pando         BO-N
# 198      Bolivia      Potosi         BO-P
# 231      Bolivia  Santa Cruz         BO-S
# 264      Bolivia      Tarija         BO-T
#       country_name            adm1_name adm1_isocode
# 297         Brazil                 Acre        BR-AC
# 1750        Brazil              Alagoas        BR-AL
# 3206        Brazil                Amapa        BR-AP
# 4653        Brazil             Amazonas        BR-AM
# 6107        Brazil                Bahia        BR-BA
# 7563        Brazil                Ceara        BR-CE
# 9018        Brazil       Espirito Santo        BR-ES
# 10473       Brazil     Federal District        BR-DF
# 11928       Brazil                Goias        BR-GO
# 13384       Brazil             Maranhao        BR-MA
# 14838       Brazil          Mato Grosso        BR-MT
# 16291       Brazil   Mato Grosso do Sul        BR-MS
# 17744       Brazil         Minas Gerais        BR-MG
# 19200       Brazil                 Para        BR-PA
# 20653       Brazil              Paraiba        BR-PB
# 22109       Brazil               Parana        BR-PR
# 23563       Brazil           Pernambuco        BR-PE
# 25019       Brazil                Piaui        BR-PI
# 26468       Brazil  Rio Grande do Norte        BR-RN
# 27919       Brazil    Rio Grande do Sul        BR-RS
# 29375       Brazil       Rio de Janeiro        BR-RJ
# 30831       Brazil             Rondonia        BR-RO
# 32283       Brazil              Roraima        BR-RR
# 33728       Brazil       Santa Catarina        BR-SC
# 35182       Brazil            Sao Paulo        BR-SP
# 36636       Brazil              Sergipe        BR-SE
# 38088       Brazil            Tocantins        BR-TO
#        country_name              adm1_name adm1_isocode
# 39540         Chile                  Aisen        CL-AI
# 43916         Chile            Antofagasta        CL-AN
# 48292         Chile              Araucania        CL-AR
# 52668         Chile     Arica y Parinacota        CL-AP
# 57044         Chile                Atacama        CL-AT
# 61420         Chile                 Biobio        CL-BI
# 65796         Chile               Coquimbo        CL-CO
# 70172         Chile              Los Lagos        CL-LL
# 74548         Chile               Los Rios        CL-LR
# 78924         Chile             Magallanes        CL-MA
# 83300         Chile                  Maule        CL-ML
# 87676         Chile              O'Higgins        CL-LI
# 92052         Chile  Santiago Metropolitan        CL-RM
# 96428         Chile               Tarapaca        CL-TA
# 100804        Chile             Valparaiso        CL-VS
# 105180        Chile                  Ñuble        CL-NB
#        country_name                 adm1_name adm1_isocode
# 109556     Colombia                  Amazonas       CO-AMA
# 109905     Colombia                 Antioquia       CO-ANT
# 110254     Colombia                    Arauca       CO-ARA
# 110603     Colombia                 Atlantico       CO-ATL
# 110952     Colombia               Bogota D.C.        CO-DC
# 111301     Colombia                   Bolivar       CO-BOL
# 111650     Colombia                    Boyaca       CO-BOY
# 111999     Colombia                    Caldas       CO-CAL
# 112348     Colombia                   Caqueta       CO-CAQ
# 112697     Colombia                  Casanare       CO-CAS
# 113046     Colombia                     Cauca       CO-CAU
# 113395     Colombia                     Cesar       CO-CES
# 113744     Colombia                     Choco       CO-CHO
# 114093     Colombia                   Cordoba       CO-COR
# 114442     Colombia              Cundinamarca       CO-CUN
# 114791     Colombia                   Guainia       CO-GUA
# 115139     Colombia                  Guaviare       CO-GUV
# 115488     Colombia                     Huila       CO-HUI
# 115837     Colombia                La Guajira       CO-LAG
# 116186     Colombia                 Magdalena       CO-MAG
# 116535     Colombia                      Meta       CO-MET
# 116884     Colombia                    Narino       CO-NAR
# 117233     Colombia        Norte de Santander       CO-NSA
# 117582     Colombia                  Putumayo       CO-PUT
# 117931     Colombia                   Quindio       CO-QUI
# 118280     Colombia                 Risaralda       CO-RIS
# 118629     Colombia  San Andres y Providencia       CO-SAP
# 118978     Colombia                 Santander       CO-SAN
# 119327     Colombia                     Sucre       CO-SUC
# 119676     Colombia                    Tolima       CO-TOL
# 120025     Colombia           Valle del Cauca       CO-VAC
# 120374     Colombia                    Vaupes       CO-VAU
# 120721     Colombia                   Vichada       CO-VID
#        country_name                       adm1_name adm1_isocode
# 121070      Ecuador                           Azuay         EC-A
# 123606      Ecuador                         Bolivar         EC-B
# 126141      Ecuador                           Canar         EC-F
# 128673      Ecuador                          Carchi         EC-C
# 131202      Ecuador                      Chimborazo         EC-H
# 133739      Ecuador                        Cotopaxi         EC-X
# 136274      Ecuador                          El Oro         EC-O
# 138810      Ecuador                      Esmeraldas         EC-E
# 141344      Ecuador                       Galapagos         EC-W
# 143859      Ecuador                          Guayas         EC-G
# 146397      Ecuador                        Imbabura         EC-I
# 148933      Ecuador                            Loja         EC-L
# 151469      Ecuador                        Los Rios         EC-R
# 154005      Ecuador                          Manabi         EC-M
# 156541      Ecuador                 Morona-Santiago         EC-S
# 159069      Ecuador                            Napo         EC-N
# 161600      Ecuador                        Orellana         EC-D
# 164127      Ecuador                         Pastaza         EC-Y
# 166648      Ecuador                       Pichincha         EC-P
# 169186      Ecuador                     Santa Elena        EC-SE
# 171719      Ecuador  Santo Domingo de los Tsachilas        EC-SD
# 174255      Ecuador                       Sucumbios         EC-U
# 176789      Ecuador                      Tungurahua         EC-T
# 179325      Ecuador                Zamora-Chinchipe         EC-Z
#        country_name      adm1_name adm1_isocode
# 181846         Peru       Amazonas       PE-AMA
# 183497         Peru         Ancash       PE-ANC
# 185319         Peru       Apurimac       PE-APU
# 187111         Peru       Arequipa       PE-ARE
# 188933         Peru       Ayacucho       PE-AYA
# 190724         Peru      Cajamarca       PE-CAJ
# 192546         Peru         Callao       PE-CAL
# 194368         Peru          Cusco       PE-CUS
# 196190         Peru   Huancavelica       PE-HUV
# 198004         Peru        Huanuco       PE-HUC
# 199826         Peru            Ica       PE-ICA
# 201648         Peru          Junin       PE-JUN
# 203470         Peru    La Libertad       PE-LAL
# 205292         Peru     Lambayeque       PE-LAM
# 207020         Peru           Lima       PE-LIM
# 208842         Peru         Loreto       PE-LOR
# 210660         Peru  Madre de Dios       PE-MDD
# 212176         Peru       Moquegua       PE-MOQ
# 213839         Peru          Pasco       PE-PAS
# 215405         Peru          Piura       PE-PIU
# 217227         Peru           Puno       PE-PUN
# 219049         Peru     San Martin       PE-SAM
# 220866         Peru          Tacna       PE-TAC
# 222635         Peru         Tumbes       PE-TUM
# 224329         Peru        Ucayali       PE-UCA
#        country_name         adm1_name adm1_isocode
# 226130     Paraguay     Alto Paraguay        PY-16
# 226213     Paraguay       Alto Parana        PY-10
# 226297     Paraguay           Amambay        PY-13
# 226381     Paraguay          Asuncion       PY-ASU
# 226465     Paraguay          Boqueron        PY-19
# 226549     Paraguay          Caaguazu         PY-5
# 226633     Paraguay           Caazapa         PY-6
# 226717     Paraguay         Canindeyu        PY-14
# 226801     Paraguay           Central        PY-11
# 226885     Paraguay        Concepcion         PY-1
# 226969     Paraguay        Cordillera         PY-3
# 227053     Paraguay            Guaira         PY-4
# 227137     Paraguay            Itapua         PY-7
# 227221     Paraguay          Misiones         PY-8
# 227305     Paraguay          Neembucu        PY-12
# 227388     Paraguay         Paraguari         PY-9
# 227472     Paraguay  Presidente Hayes        PY-15
# 227555     Paraguay         San Pedro         PY-2
#        country_name       adm1_name adm1_isocode
# 227639      Uruguay         Artigas        UY-AR
# 227708      Uruguay       Canelones        UY-CA
# 227777      Uruguay     Cerro Largo        UY-CL
# 227846      Uruguay         Colonia        UY-CO
# 227915      Uruguay         Durazno        UY-DU
# 227984      Uruguay          Flores        UY-FS
# 228053      Uruguay         Florida        UY-FD
# 228122      Uruguay       Lavalleja        UY-LA
# 228191      Uruguay       Maldonado        UY-MA
# 228260      Uruguay      Montevideo        UY-MO
# 228329      Uruguay        Paysandu        UY-PA
# 228398      Uruguay       Rio Negro        UY-RN
# 228467      Uruguay          Rivera        UY-RV
# 228536      Uruguay           Rocha        UY-RO
# 228605      Uruguay           Salto        UY-SA
# 228674      Uruguay        San Jose        UY-SJ
# 228743      Uruguay         Soriano        UY-SO
# 228812      Uruguay      Tacuarembo        UY-TA
# 228881      Uruguay  Treinta y Tres        UY-TT

# %%
nam.to_csv('./data/coun_adm.csv')

# %%
cdf = pd.read_csv('./data/city_data.csv',na_values='QuantityMagnitude[Missing["NotAvailable"]]')
cdf['Elevation'] = cdf['Elevation']/1000

# %%
plt.scatter(cdf['Population'],cdf['Elevation'],s=cdf['Population']/10000)

# %%
g1= cdf.groupby('AdministrativeDivision')
g= cdf.groupby('Country')

# %%
g['Population'].sum()
# Out:
# Country
# Bolivia       6480392
# Brazil      157831577
# Chile        17943835
# Colombia     39736325
# Ecuador      10688524
# Paraguay      4470748
# Peru         21902526
# Uruguay       3091253
# Name: Population, dtype: int64

# %%
c1 = cdf[cdf['Elevation'].notna()].copy()
c1['pop_el'] = c1['Population']*c1['Elevation']

# %%
g1 = c1.groupby('AdministrativeDivision')

# %%
wh = (g1['pop_el'].sum()/g1['Population'].sum())
wh.name = 'weighted_height'
div = wh.to_frame()

# %%
div['pop'] = g1['Population'].sum()

# %%
from statsmodels.stats.weightstats import DescrStatsW

# %%
st = {}
for g,v in g1:
    values = v['Elevation']
    weights = v['Population']
    st[g]=DescrStatsW(values, weights=weights, ddof=1).std
st = pd.Series(st)

# %%
div['stw']=st

# %%
d1 = div.sort_values('pop',ascending=False)

# %%
f,ax = plt.subplots(dpi=300)

ax.scatter(d1['pop'],d1['weighted_height'],s=d1['pop']/100000,edgecolors='k')
ax.errorbar(d1['pop'],d1['weighted_height'],yerr=d1['stw'],lw=0,elinewidth=1,zorder=100,c='k')
ax.set_xscale('log')

# %%
df['dt']=pd.to_datetime(df['date'])
df1 = df.set_index('dt')

# %%
df2=df1.groupby(['adm1_isocode',pd.Grouper(freq='M')]).sum()['deaths'].unstack().T

# %%
df3 = df2['2019-01-01':'2019-12-31']

# %%
df3.index = df3.index.month

# %%
df3.isna().sum().sum()
# Out:
# 0

# %%
mm = df2['2020-03':'2024']

# %%
mm.index = mm.index.month

# %%
m2 = mm.sum()/(mm * 0 + df3).sum()

# %%
m1 = (mm/df3).mean()

# %%
m1.plot()
m2.plot()
ax = plt.gca()
ax.axhline(1)
ax.set_ylim(0.5,3)
# Out:
# (0.5, 3.0)

# %%
adm_dic=pd.read_csv('./data/adm_dic.csv')

# %%
m2.name='ratio'
m3 = m2.to_frame()

# %%
f1 = pd.merge(m2,adm_dic,left_index=True, right_on='admi',how='inner',
         validate='1:1')

# %%
f1
# Out:
#         ratio                    mname        pop  country             adm  \
# 0    1.477348            Beni, Bolivia   421196.0  Bolivia            Beni
# 2    1.483096      Cochabamba, Bolivia  1930143.0  Bolivia      Cochabamba
# 1    1.369958      Chuquisaca, Bolivia   576153.0  Bolivia      Chuquisaca
# 3    1.705101          La Paz, Bolivia  2706359.0  Bolivia          La Paz
# 5    1.860465           Pando, Bolivia   110436.0  Bolivia           Pando
# ..        ...                      ...        ...      ...             ...
# 166  0.888889           Salto, Uruguay   124878.0  Uruguay           Salto
# 167  0.962594        San Jose, Uruguay   108309.0  Uruguay        San Jose
# 168  0.964088         Soriano, Uruguay    82595.0  Uruguay         Soriano
# 169  0.889441      Tacuarembo, Uruguay    90053.0  Uruguay      Tacuarembo
# 170  1.002387  Treinta y Tres, Uruguay    48134.0  Uruguay  Treinta y Tres
#
#       admi
# 0     BO-B
# 2     BO-C
# 1     BO-H
# 3     BO-L
# 5     BO-N
# ..     ...
# 166  UY-SA
# 167  UY-SJ
# 168  UY-SO
# 169  UY-TA
# 170  UY-TT
#
# [171 rows x 6 columns]

# %%
f2 = pd.merge(d1.drop('pop',axis=1),f1,left_index=True,
         right_on='mname',validate='1:1')

f2 = f2.sort_values('pop',ascending=False)
f2 = f2[f2['ratio']<3]
bo=f2['country']=='Brazil'
# f2 = f2[bo]

cme = f2.groupby('country').median()

f2 = pd.merge(cme,f2,left_on='country',right_on='country',suffixes=['_r',''])
# f2['ratio']=f2['ratio']/f2['ratio_r']

# %%
f,ax= plt.subplots(dpi=300)
ax.scatter(
    f2['weighted_height'],
    f2['ratio'],
    s=f2['pop']/100000,
    edgecolors='k'
)
# ax.set_ylim(.5,3)

# %%
mea = f2['ratio'].mean()

wmea = (f2['ratio']*f2['pop']).sum()/f2['pop'].sum()

# %%
co = f2['country']

# %%
dic_ = co.drop_duplicates().reset_index(drop=True).reset_index().set_index('country')['index'].to_dict()

# %%
f2['ci']=f2['country'].replace(dic_)

# %%
cm = plt.get_cmap('tab10')

# %%
cs = [cm(i) for l,i in f2['ci'].items()]

# %%
from sklearn.linear_model import QuantileRegressor,LinearRegression

# %%
qr = QuantileRegressor(alpha=0)
qr1 = LinearRegression()
qr2 = LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler

# %%
f2_ = f2.sort_values('weighted_height')
X = f2_[['weighted_height']]
y = f2_[['ratio']]

# %%
s1 = StandardScaler()
s2 = StandardScaler()

# %%
X1 = s1.fit_transform(X)
y1 = s2.fit_transform(y)

# %%
qr.fit(X1,y1[:,0])
qr1.fit(X1,y1[:,0])
qr2.fit(X,y.values[:,0])
# Out:
# LinearRegression()

# %%
yp11 = qr.predict(X1)
yp12 = qr1.predict(X1)
yp13 = qr2.predict(X)

# %%
yp111 = s2.inverse_transform(yp11.reshape(-1,1))[:,0]
yp112 = s2.inverse_transform(yp12.reshape(-1,1))[:,0]

# %%
plt.plot(X.values[:,0],yp111)
plt.plot(X.values[:,0],yp112)
plt.plot(X.values[:,0],yp13)
plt.scatter(X.values[:,0],y.values[:,0])
plt.gca().set_ylim(.75,2.8)
# Out:
# (0.75, 2.8)

# %%
means = {}
wmeans_ = {}
fits = {}
f_xy = {}
for c in dic_.keys():
    boo = f2['country']==c
    means[c]=f2[boo]['ratio'].mean()
    _f = f2[boo].sort_values('weighted_height')
    wm = (_f['ratio'] * _f['pop']).sum()/_f['pop'].sum()
    wmeans_[c]=wm
    
    
    lr = QuantileRegressor(alpha=0)
#     lr = LinearRegression()
    _X = _f[['weighted_height']]
    _y = _f['ratio']
    lr.fit(_X,_y)
    fits[c] = lr
    f_xy[c] = [_X.values[:,0],lr.predict(_X)]

# %%
means = pd.Series(means).sort_values(ascending=False).to_dict()
dic = {}
wmeans = {}
for i,v in means.items():
    dic[i] = dic_[i]
    wmeans[i] = wmeans_[i]

# %%
pd.Series(means).plot.bar(alpha=.5)
pd.Series(wmeans).plot.bar(alpha=.5,color='r',width=.1)
# Out:
# <AxesSubplot:>

# %%
doff = {
    'Peru': 0,
     'Bolivia': 0,
     'Ecuador': .01,
     'Colombia': -.01,
     'Brazil': 0,
     'Paraguay': 0,
     'Chile': 0,
     'Uruguay': 0
}

# %%
fy = f' y = {qr2.coef_[0]:.2f}x + {qr2.intercept_:.2f}'

# %%
f,ax= plt.subplots(dpi=200,figsize=(5,6))
ax.scatter(
    f2['weighted_height'],
    f2['ratio'],
    s=f2['pop']/100000,
    edgecolors=cs,
    lw=2,
    facecolor='none'
)
ax.set_ylim(.75,2.75)
ax.axhline(wmea,c='.5',ls='--',lw=1)
ax.plot(X.values[:,0],yp13,ls=':',c='.5',lw=1)
ax.text(X.values[-1,0],yp13[-1],fy,va='center',fontsize=6,c='.5')


sns.despine(f)
ax.set_ylabel('razón exceso mortandad')
ax.set_xlabel('elevación [km sobre el nivel del mar]')

# al = {0:'bottom',1:'top'}

for i,c in enumerate(dic.keys()):
    ax.axhline(wmeans[c],alpha=.3,lw=1,ls='--',c=cm(dic[c]))
#   ax.plot(*f_xy[c],ls='-.',lw=1,alpha=.5)
#   ax.text(.5,1-i/20,c,transform=ax.transAxes,c=cm(dic[c]))
    ax.text(4.1,wmeans[c]+doff[c],f'$\overline{{x}}=${means[c]:.2f}|{c}',
            fontsize=5,c=cm(dic[c]),va='center')
    pass

ax.text(4.1,wmea,f'$\overline{{x}}=${mea:.2f}|prom regional',
        fontsize=5,c='.5',va='center')

for i,r in f2.iterrows():
    ax.text(r['weighted_height'],r['ratio'],
           r['adm'][:10], fontsize = (r['pop'])**.5/5000+2,
            c='.7'
           )
xx = [2.7,2.7,2.7]
yy = [2.65,2.55,2.49]
pp = [5e7,5e6,5e5]
ax.scatter(
    xx,
    yy,
    s=np.array(pp)/100000,
    lw=2,
    facecolor='none',
    edgecolor='.9')

for x,y,p in zip(xx,yy,pp):
    ax.text(x+.75,y,f'{int(p):,}',va='center',ha='right',fontsize=4,c='.8')
    
ax.text(xx[0]+.1,2.75,'Habitantes (approx.)',fontsize=7,c='.7',ha='center')
f.tight_layout()
f.savefig('reg_alt.pdf')

# %%
sns.regplot(data = f2,x='weighted_height',y='ratio')
# Out:
# <AxesSubplot:xlabel='weighted_height', ylabel='ratio'>

# %%
f2
# Out:
#      country  weighted_height_r     stw_r   ratio_r     pop_r  \
# 0    Bolivia           2.647915  0.241489  1.483096  576153.0
# 1    Bolivia           2.647915  0.241489  1.483096  576153.0
# 2    Bolivia           2.647915  0.241489  1.483096  576153.0
# 3    Bolivia           2.647915  0.241489  1.483096  576153.0
# 4    Bolivia           2.647915  0.241489  1.483096  576153.0
# ..       ...                ...       ...       ...       ...
# 160  Uruguay           0.039539  0.019047  0.934766   84698.0
# 161  Uruguay           0.039539  0.019047  0.934766   84698.0
# 162  Uruguay           0.039539  0.019047  0.934766   84698.0
# 163  Uruguay           0.039539  0.019047  0.934766   84698.0
# 164  Uruguay           0.039539  0.019047  0.934766   84698.0
#
#      weighted_height       stw     ratio                    mname        pop  \
# 0           0.424662  0.179002  1.573589      Santa Cruz, Bolivia  3412921.0
# 1           3.860132  0.421739  1.705101          La Paz, Bolivia  2706359.0
# 2           2.647915  0.241489  1.483096      Cochabamba, Bolivia  1930143.0
# 3           3.803522  0.268544  1.383116          Potosi, Bolivia   823517.0
# 4           2.743848  0.273781  1.369958      Chuquisaca, Bolivia   576153.0
# ..               ...       ...       ...                      ...        ...
# 160         0.129979  0.047283  0.840125       Lavalleja, Uruguay    58815.0
# 161         0.107898  0.016420  0.889109         Durazno, Uruguay    57088.0
# 162         0.038284  0.027465  0.884236       Rio Negro, Uruguay    54765.0
# 163         0.070170  0.067115  1.002387  Treinta y Tres, Uruguay    48134.0
# 164         0.130000  0.000000  0.882653          Flores, Uruguay    25050.0
#
#                 adm   admi  ci
# 0        Santa Cruz   BO-S   0
# 1            La Paz   BO-L   0
# 2        Cochabamba   BO-C   0
# 3            Potosi   BO-P   0
# 4        Chuquisaca   BO-H   0
# ..              ...    ...  ..
# 160       Lavalleja  UY-LA   7
# 161         Durazno  UY-DU   7
# 162       Rio Negro  UY-RN   7
# 163  Treinta y Tres  UY-TT   7
# 164          Flores  UY-FS   7
#
# [165 rows x 13 columns]
